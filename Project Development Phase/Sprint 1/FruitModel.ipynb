# %% [markdown]
# ## **FRUIT MODEL**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/NalaiyaThiran/Dataset/fruit-dataset.zip")
zip_ref.extractall()
zip_ref.close()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
import random
import cv2
from tensorflow.keras import layers, models
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
import pickle
import zipfile
tf.__version__
# Out:
# '2.9.2'

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)
# Out:
# Number of replicas: 1

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
batch_size = 32
IMAGE_SIZE = [128, 128]
EPOCHS = 25

# %%
TRAIN_PATH = "/content/fruit-dataset/train"

FRUIT_TRAIN_CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(TRAIN_PATH + "*/*"))])
FRUIT_TRAIN_CLASS_NAMES
# Out:
# array(['Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy',
#        'Apple___Black_rot', 'Peach___Bacterial_spot', 'Apple___healthy',
#        'Peach___healthy'], dtype='<U35')

# %%
files_train_count = []
for i,f in enumerate(FRUIT_TRAIN_CLASS_NAMES):
    folder_path = os.path.join(TRAIN_PATH, f)
    for path in os.listdir(os.path.join(folder_path)):
        files_train_count.append(['{}/{}'.format(folder_path,path), f, i])
fruits_train_df = pd.DataFrame(files_train_count, columns=['filepath', 'class_name', 'label'])
fruits_train_df.head()
# Out:
#                                             filepath  \
# 0  /content/fruit-dataset/train/Corn_(maize)___No...
# 1  /content/fruit-dataset/train/Corn_(maize)___No...
# 2  /content/fruit-dataset/train/Corn_(maize)___No...
# 3  /content/fruit-dataset/train/Corn_(maize)___No...
# 4  /content/fruit-dataset/train/Corn_(maize)___No...
#
#                             class_name  label
# 0  Corn_(maize)___Northern_Leaf_Blight      0
# 1  Corn_(maize)___Northern_Leaf_Blight      0
# 2  Corn_(maize)___Northern_Leaf_Blight      0
# 3  Corn_(maize)___Northern_Leaf_Blight      0
# 4  Corn_(maize)___Northern_Leaf_Blight      0

# %%
fruits_train_df.class_name.value_counts()
# Out:
# Peach___Bacterial_spot                 1804
# Apple___healthy                        1200
# Corn_(maize)___healthy                  861
# Corn_(maize)___Northern_Leaf_Blight     768
# Apple___Black_rot                       440
# Peach___healthy                         311
# Name: class_name, dtype: int64

# %%
quantidade_por_class = 310
fruits_train_df = pd.concat([fruits_train_df[fruits_train_df['class_name']== i][:quantidade_por_class] for i in FRUIT_TRAIN_CLASS_NAMES])

# %%
fruits_train_df.class_name.value_counts()
# Out:
# Corn_(maize)___Northern_Leaf_Blight    310
# Corn_(maize)___healthy                 310
# Apple___Black_rot                      310
# Peach___Bacterial_spot                 310
# Apple___healthy                        310
# Peach___healthy                        310
# Name: class_name, dtype: int64

# %%
image = cv2.imread(fruits_train_df.filepath[100])
imgplot = plt.imshow(image)
plt.show()

# %%
x_train = fruits_train_df['filepath']
y_train = fruits_train_df['label']

# %%
x_train_tensor = tf.convert_to_tensor(x_train.values, dtype=tf.string)
y_train_tensor = tf.convert_to_tensor(y_train.values)

# %%
TEST_PATH = "/content/fruit-dataset/test"

FRUIT_TEST_CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(TEST_PATH + "*/*"))])
FRUIT_TEST_CLASS_NAMES
# Out:
# array(['Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy',
#        'Apple___Black_rot', 'Peach___Bacterial_spot', 'Apple___healthy',
#        'Peach___healthy'], dtype='<U35')

# %%
files_test_count = []
for i,f in enumerate(FRUIT_TEST_CLASS_NAMES):
    folder_test_path = os.path.join(TEST_PATH, f)
    for path in os.listdir(os.path.join(folder_test_path)):
        files_test_count.append(['{}/{}'.format(folder_test_path,path), f, i])
fruits_test_df = pd.DataFrame(files_test_count, columns=['filepath', 'class_name', 'label'])
fruits_test_df.head()
# Out:
#                                             filepath  \
# 0  /content/fruit-dataset/test/Corn_(maize)___Nor...
# 1  /content/fruit-dataset/test/Corn_(maize)___Nor...
# 2  /content/fruit-dataset/test/Corn_(maize)___Nor...
# 3  /content/fruit-dataset/test/Corn_(maize)___Nor...
# 4  /content/fruit-dataset/test/Corn_(maize)___Nor...
#
#                             class_name  label
# 0  Corn_(maize)___Northern_Leaf_Blight      0
# 1  Corn_(maize)___Northern_Leaf_Blight      0
# 2  Corn_(maize)___Northern_Leaf_Blight      0
# 3  Corn_(maize)___Northern_Leaf_Blight      0
# 4  Corn_(maize)___Northern_Leaf_Blight      0

# %%
fruits_test_df.class_name.value_counts()
# Out:
# Peach___Bacterial_spot                 493
# Apple___healthy                        445
# Corn_(maize)___healthy                 301
# Corn_(maize)___Northern_Leaf_Blight    217
# Apple___Black_rot                      181
# Peach___healthy                         49
# Name: class_name, dtype: int64

# %%
quantidade_por_class = 49
fruits_test_df = pd.concat([fruits_test_df[fruits_test_df['class_name']== i][:quantidade_por_class] for i in FRUIT_TEST_CLASS_NAMES])

# %%
image = cv2.imread(fruits_test_df.filepath[40])
imgplot = plt.imshow(image)
plt.show()

# %%
x_test = fruits_test_df['filepath']
y_test = fruits_test_df['label']

# %%
x_test_tensor = tf.convert_to_tensor(x_test.values, dtype=tf.string)
y_test_tensor = tf.convert_to_tensor(y_test.values)

# %%
train_data = tf.data.Dataset.from_tensor_slices((x_train_tensor, y_train_tensor))
test_data = tf.data.Dataset.from_tensor_slices((x_test_tensor, y_test_tensor))

# %%
def map_fn(path, label):
    image = tf.image.decode_jpeg(tf.io.read_file(path))
    return image, label
#apply the function
train_data_img = train_data.map(map_fn)
test_data_img = test_data.map(map_fn)

# %%
fig, ax = plt.subplots(1,2, figsize = (15,5))
for i,l in train_data_img.take(1):
    ax[0].set_title('Image from train dataset');
    ax[0].imshow(i);
for i,l in test_data_img.take(1):
    ax[1].set_title('Image from test dataset');
    ax[1].imshow(i);

# %%
def preprocessing(image, label):
    """
    returns a image that is reshaped and normalized
    """
    image = tf.cast(image, tf.float32)
    image = image / 255.
    image = tf.image.resize(image, IMAGE_SIZE)
    
    return image, label


train_data_norm = train_data_img.map(preprocessing)
test_data_norm = test_data_img.map(preprocessing)

# %%
fig, ax = plt.subplots(1,2, figsize = (15,5))
for i,l in train_data_norm.take(1):
    ax[0].set_title('Image from train dataset');
    ax[0].imshow(i);
for i,l in test_data_norm.take(1):
    ax[1].set_title('Image from test dataset');
    ax[1].imshow(i);

# %%
train_batches = train_data_norm.batch(batch_size)
test_batches = test_data_norm.batch(batch_size)

for i, l in train_batches.take(1):
    print('Train Data Shape',i.shape)
for i, l in test_batches.take(1):
    print('Test Data Shape',i.shape)
# Out:
# Train Data Shape (32, 128, 128, 3)
# Test Data Shape (32, 128, 128, 3)

# %%
LeNet = models.Sequential()
LeNet.add(layers.Conv2D(6, (5,5), activation = 'relu', input_shape = (128, 128, 3)))
LeNet.add(layers.AveragePooling2D())
LeNet.add(layers.Conv2D(16, (5,5), activation = 'relu'))
LeNet.add(layers.AveragePooling2D())
LeNet.add(layers.Flatten())
LeNet.add(layers.Dense(255, activation='relu'))
LeNet.add(layers.Dropout(0.2))
LeNet.add(layers.Dense(124, activation='relu'))
LeNet.add(layers.Dropout(0.2))
LeNet.add(layers.Dense(84, activation='relu'))
LeNet.add(layers.Dense(43, activation='sigmoid'))
LeNet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 124, 124, 6)       456
#
#  average_pooling2d (AverageP  (None, 62, 62, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 58, 58, 16)        2416
#
#  average_pooling2d_1 (Averag  (None, 29, 29, 16)       0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 13456)             0
#
#  dense (Dense)               (None, 255)               3431535
#
#  dropout (Dropout)           (None, 255)               0
#
#  dense_1 (Dense)             (None, 124)               31744
#
#  dropout_1 (Dropout)         (None, 124)               0
#
#  dense_2 (Dense)             (None, 84)                10500
#
#  dense_3 (Dense)             (None, 43)                3655
#
# =================================================================
# Total params: 3,480,306
# Trainable params: 3,480,306
# Non-trainable params: 0
# _________________________________________________________________

# %%
LeNet.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = LeNet.fit(train_batches, epochs=100,batch_size = 16,validation_data=(test_batches))
# Out:
# Epoch 1/100
# 59/59 [==============================] - 52s 850ms/step - loss: 6.2402 - accuracy: 0.1946 - val_loss: 3.3547 - val_accuracy: 0.1497
# Epoch 2/100
# 59/59 [==============================] - 34s 580ms/step - loss: 2.8868 - accuracy: 0.1323 - val_loss: 2.3369 - val_accuracy: 0.1667
# Epoch 3/100
# 59/59 [==============================] - 36s 610ms/step - loss: 2.5506 - accuracy: 0.0022 - val_loss: 2.0701 - val_accuracy: 0.1667
# Epoch 4/100
# 59/59 [==============================] - 37s 635ms/step - loss: 2.3367 - accuracy: 0.0016 - val_loss: 2.1681 - val_accuracy: 0.1667
# Epoch 5/100
# 59/59 [==============================] - 38s 640ms/step - loss: 2.0911 - accuracy: 0.0258 - val_loss: 2.0785 - val_accuracy: 0.1667
# Epoch 6/100
# 59/59 [==============================] - 34s 581ms/step - loss: 2.0327 - accuracy: 0.0645 - val_loss: 1.8689 - val_accuracy: 0.1667
# Epoch 7/100
# 59/59 [==============================] - 34s 581ms/step - loss: 1.9977 - accuracy: 0.1591 - val_loss: 2.0328 - val_accuracy: 0.1667
# Epoch 8/100
# 59/59 [==============================] - 35s 598ms/step - loss: 2.1046 - accuracy: 0.0290 - val_loss: 1.8449 - val_accuracy: 0.1667
# Epoch 9/100
# 59/59 [==============================] - 34s 578ms/step - loss: 2.0892 - accuracy: 0.0059 - val_loss: 1.8373 - val_accuracy: 0.1667
# Epoch 10/100
# 59/59 [==============================] - 36s 617ms/step - loss: 2.0256 - accuracy: 0.1344 - val_loss: 1.8841 - val_accuracy: 0.1667
# Epoch 11/100
# 59/59 [==============================] - 34s 579ms/step - loss: 1.9852 - accuracy: 0.1677 - val_loss: 1.9461 - val_accuracy: 0.1667
# Epoch 12/100
# 59/59 [==============================] - 34s 579ms/step - loss: 1.9217 - accuracy: 0.1661 - val_loss: 1.8239 - val_accuracy: 0.1667
# Epoch 13/100
# 59/59 [==============================] - 36s 613ms/step - loss: 1.8986 - accuracy: 0.1059 - val_loss: 1.8094 - val_accuracy: 0.1667
# Epoch 14/100
# 59/59 [==============================] - 34s 577ms/step - loss: 1.8858 - accuracy: 0.0296 - val_loss: 1.7909 - val_accuracy: 0.2721
# Epoch 15/100
# 59/59 [==============================] - 34s 578ms/step - loss: 2.1477 - accuracy: 0.1581 - val_loss: 1.8282 - val_accuracy: 0.1667
# Epoch 16/100
# 59/59 [==============================] - 34s 579ms/step - loss: 1.8941 - accuracy: 0.1624 - val_loss: 1.7948 - val_accuracy: 0.1939
# Epoch 17/100
# 59/59 [==============================] - 36s 617ms/step - loss: 1.8752 - accuracy: 0.1339 - val_loss: 1.7590 - val_accuracy: 0.2177
# Epoch 18/100
# 59/59 [==============================] - 34s 577ms/step - loss: 1.8677 - accuracy: 0.0699 - val_loss: 1.7959 - val_accuracy: 0.1701
# Epoch 19/100
# 59/59 [==============================] - 37s 618ms/step - loss: 1.8621 - accuracy: 0.0285 - val_loss: 1.7267 - val_accuracy: 0.2279
# Epoch 20/100
# 59/59 [==============================] - 34s 582ms/step - loss: 1.7119 - accuracy: 0.0989 - val_loss: 1.5221 - val_accuracy: 0.3537
# Epoch 21/100
# 59/59 [==============================] - 34s 582ms/step - loss: 1.6419 - accuracy: 0.2022 - val_loss: 1.5815 - val_accuracy: 0.3435
# Epoch 22/100
# 59/59 [==============================] - 34s 582ms/step - loss: 1.6223 - accuracy: 0.2710 - val_loss: 1.2911 - val_accuracy: 0.5136
# Epoch 23/100
# 59/59 [==============================] - 37s 621ms/step - loss: 1.4905 - accuracy: 0.3043 - val_loss: 1.2427 - val_accuracy: 0.5102
# Epoch 24/100
# 59/59 [==============================] - 34s 576ms/step - loss: 1.3865 - accuracy: 0.3430 - val_loss: 1.2599 - val_accuracy: 0.5102
# Epoch 25/100
# 59/59 [==============================] - 34s 579ms/step - loss: 1.3473 - accuracy: 0.3930 - val_loss: 1.3181 - val_accuracy: 0.5306
# Epoch 26/100
# 59/59 [==============================] - 34s 577ms/step - loss: 1.3186 - accuracy: 0.3699 - val_loss: 1.2918 - val_accuracy: 0.4864
# Epoch 27/100
# 59/59 [==============================] - 34s 581ms/step - loss: 1.3323 - accuracy: 0.3016 - val_loss: 1.1355 - val_accuracy: 0.5408
# Epoch 28/100
# 59/59 [==============================] - 34s 580ms/step - loss: 1.1158 - accuracy: 0.4156 - val_loss: 1.1584 - val_accuracy: 0.5306
# Epoch 29/100
# 59/59 [==============================] - 34s 582ms/step - loss: 1.1408 - accuracy: 0.3935 - val_loss: 1.1478 - val_accuracy: 0.5442
# Epoch 30/100
# 59/59 [==============================] - 36s 618ms/step - loss: 1.0066 - accuracy: 0.4516 - val_loss: 1.1220 - val_accuracy: 0.5748
# Epoch 31/100
# 59/59 [==============================] - 34s 582ms/step - loss: 0.9768 - accuracy: 0.4613 - val_loss: 1.1675 - val_accuracy: 0.5612
# Epoch 32/100
# 59/59 [==============================] - 34s 581ms/step - loss: 0.8628 - accuracy: 0.5011 - val_loss: 1.4496 - val_accuracy: 0.4626
# Epoch 33/100
# 59/59 [==============================] - 34s 581ms/step - loss: 0.9298 - accuracy: 0.4871 - val_loss: 1.1391 - val_accuracy: 0.5646
# Epoch 34/100
# 59/59 [==============================] - 34s 581ms/step - loss: 0.7670 - accuracy: 0.5473 - val_loss: 1.4145 - val_accuracy: 0.5612
# Epoch 35/100
# 59/59 [==============================] - 34s 577ms/step - loss: 0.8356 - accuracy: 0.5425 - val_loss: 7.3852 - val_accuracy: 0.3401
# Epoch 36/100
# 59/59 [==============================] - 34s 579ms/step - loss: 1.9515 - accuracy: 0.4140 - val_loss: 1.9024 - val_accuracy: 0.2381
# Epoch 37/100
# 59/59 [==============================] - 34s 578ms/step - loss: 1.1983 - accuracy: 0.5242 - val_loss: 3.4582 - val_accuracy: 0.3469
# Epoch 38/100
# 59/59 [==============================] - 34s 578ms/step - loss: 1.2349 - accuracy: 0.5559 - val_loss: 1.3861 - val_accuracy: 0.5000
# Epoch 39/100
# 59/59 [==============================] - 34s 577ms/step - loss: 0.8496 - accuracy: 0.7027 - val_loss: 1.5024 - val_accuracy: 0.4422
# Epoch 40/100
# 59/59 [==============================] - 34s 576ms/step - loss: 0.8311 - accuracy: 0.6403 - val_loss: 1.3288 - val_accuracy: 0.5510
# Epoch 41/100
# 59/59 [==============================] - 34s 574ms/step - loss: 0.7681 - accuracy: 0.6683 - val_loss: 1.4268 - val_accuracy: 0.5544
# Epoch 42/100
# 59/59 [==============================] - 34s 578ms/step - loss: 0.7348 - accuracy: 0.7188 - val_loss: 1.9937 - val_accuracy: 0.6054
# Epoch 43/100
# 59/59 [==============================] - 36s 607ms/step - loss: 0.8665 - accuracy: 0.6855 - val_loss: 1.6276 - val_accuracy: 0.5238
# Epoch 44/100
# 59/59 [==============================] - 34s 577ms/step - loss: 0.8208 - accuracy: 0.6651 - val_loss: 1.3207 - val_accuracy: 0.5612
# Epoch 45/100
# 59/59 [==============================] - 34s 579ms/step - loss: 0.6369 - accuracy: 0.7231 - val_loss: 1.3936 - val_accuracy: 0.5748
# Epoch 46/100
# 59/59 [==============================] - 34s 578ms/step - loss: 0.5389 - accuracy: 0.7790 - val_loss: 1.4906 - val_accuracy: 0.5748
# Epoch 47/100
# 59/59 [==============================] - 34s 581ms/step - loss: 0.4768 - accuracy: 0.8000 - val_loss: 1.6825 - val_accuracy: 0.5918
# Epoch 48/100
# 59/59 [==============================] - 34s 578ms/step - loss: 0.4814 - accuracy: 0.8043 - val_loss: 1.6859 - val_accuracy: 0.6020
# Epoch 49/100
# 59/59 [==============================] - 34s 576ms/step - loss: 0.4215 - accuracy: 0.8253 - val_loss: 1.7167 - val_accuracy: 0.6088
# Epoch 50/100
# 59/59 [==============================] - 36s 602ms/step - loss: 0.6776 - accuracy: 0.8349 - val_loss: 2.1339 - val_accuracy: 0.6054
# Epoch 51/100
# 59/59 [==============================] - 34s 571ms/step - loss: 0.6400 - accuracy: 0.8075 - val_loss: 1.5329 - val_accuracy: 0.5646
# Epoch 52/100
# 59/59 [==============================] - 34s 570ms/step - loss: 0.5135 - accuracy: 0.7876 - val_loss: 1.5197 - val_accuracy: 0.6122
# Epoch 53/100
# 59/59 [==============================] - 34s 569ms/step - loss: 0.3545 - accuracy: 0.8360 - val_loss: 1.8052 - val_accuracy: 0.5986
# Epoch 54/100
# 59/59 [==============================] - 34s 570ms/step - loss: 0.2876 - accuracy: 0.8973 - val_loss: 1.9054 - val_accuracy: 0.6224
# Epoch 55/100
# 59/59 [==============================] - 34s 572ms/step - loss: 0.2594 - accuracy: 0.9000 - val_loss: 2.1804 - val_accuracy: 0.5782
# Epoch 56/100
# 59/59 [==============================] - 36s 602ms/step - loss: 0.3054 - accuracy: 0.8946 - val_loss: 1.9639 - val_accuracy: 0.6088
# Epoch 57/100
# 59/59 [==============================] - 34s 571ms/step - loss: 0.1977 - accuracy: 0.9414 - val_loss: 2.0486 - val_accuracy: 0.5884
# Epoch 58/100
# 59/59 [==============================] - 34s 569ms/step - loss: 0.1547 - accuracy: 0.9597 - val_loss: 2.3106 - val_accuracy: 0.5918
# Epoch 59/100
# 59/59 [==============================] - 34s 572ms/step - loss: 0.1580 - accuracy: 0.9457 - val_loss: 2.1716 - val_accuracy: 0.6088
# Epoch 60/100
# 59/59 [==============================] - 34s 571ms/step - loss: 0.1406 - accuracy: 0.9565 - val_loss: 2.3109 - val_accuracy: 0.6327
# Epoch 61/100
# 59/59 [==============================] - 34s 571ms/step - loss: 0.0989 - accuracy: 0.9726 - val_loss: 2.4589 - val_accuracy: 0.6497
# Epoch 62/100
# 59/59 [==============================] - 34s 572ms/step - loss: 0.0836 - accuracy: 0.9753 - val_loss: 2.3308 - val_accuracy: 0.6497
# Epoch 63/100
# 59/59 [==============================] - 37s 631ms/step - loss: 0.0678 - accuracy: 0.9823 - val_loss: 2.2919 - val_accuracy: 0.6190
# Epoch 64/100
# 59/59 [==============================] - 34s 570ms/step - loss: 0.0424 - accuracy: 0.9892 - val_loss: 2.5340 - val_accuracy: 0.6463
# Epoch 65/100
# 59/59 [==============================] - 34s 571ms/step - loss: 0.0346 - accuracy: 0.9919 - val_loss: 2.4243 - val_accuracy: 0.6565
# Epoch 66/100
# 59/59 [==============================] - 34s 573ms/step - loss: 0.0272 - accuracy: 0.9935 - val_loss: 2.7097 - val_accuracy: 0.6463
# Epoch 67/100
# 59/59 [==============================] - 34s 571ms/step - loss: 0.0177 - accuracy: 0.9957 - val_loss: 2.6626 - val_accuracy: 0.6633
# Epoch 68/100
# 59/59 [==============================] - 34s 573ms/step - loss: 0.0293 - accuracy: 0.9935 - val_loss: 2.7072 - val_accuracy: 0.6735
# Epoch 69/100
# 59/59 [==============================] - 34s 572ms/step - loss: 0.0233 - accuracy: 0.9952 - val_loss: 2.6302 - val_accuracy: 0.6565
# Epoch 70/100
# 59/59 [==============================] - 36s 602ms/step - loss: 0.0153 - accuracy: 0.9968 - val_loss: 2.5941 - val_accuracy: 0.6565
# Epoch 71/100
# 59/59 [==============================] - 34s 572ms/step - loss: 0.0194 - accuracy: 0.9941 - val_loss: 2.7772 - val_accuracy: 0.6667
# Epoch 72/100
# 59/59 [==============================] - 34s 571ms/step - loss: 0.0123 - accuracy: 0.9952 - val_loss: 2.7877 - val_accuracy: 0.6531
# Epoch 73/100
# 59/59 [==============================] - 36s 602ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 2.9392 - val_accuracy: 0.6667
# Epoch 74/100
# 59/59 [==============================] - 34s 572ms/step - loss: 0.0155 - accuracy: 0.9957 - val_loss: 2.6499 - val_accuracy: 0.6361
# Epoch 75/100
# 59/59 [==============================] - 34s 572ms/step - loss: 0.0232 - accuracy: 0.9941 - val_loss: 2.7279 - val_accuracy: 0.6565
# Epoch 76/100
# 59/59 [==============================] - 35s 601ms/step - loss: 0.0167 - accuracy: 0.9962 - val_loss: 2.7166 - val_accuracy: 0.6497
# Epoch 77/100
# 59/59 [==============================] - 34s 573ms/step - loss: 0.0158 - accuracy: 0.9957 - val_loss: 2.8327 - val_accuracy: 0.6599
# Epoch 78/100
# 59/59 [==============================] - 34s 570ms/step - loss: 0.0210 - accuracy: 0.9941 - val_loss: 2.6359 - val_accuracy: 0.6837
# Epoch 79/100
# 59/59 [==============================] - 34s 570ms/step - loss: 0.0153 - accuracy: 0.9957 - val_loss: 2.5283 - val_accuracy: 0.6667
# Epoch 80/100
# 59/59 [==============================] - 34s 569ms/step - loss: 0.0116 - accuracy: 0.9968 - val_loss: 2.6550 - val_accuracy: 0.6939
# Epoch 81/100
# 59/59 [==============================] - 34s 570ms/step - loss: 0.0184 - accuracy: 0.9946 - val_loss: 2.7820 - val_accuracy: 0.6565
# Epoch 82/100
# 59/59 [==============================] - 34s 573ms/step - loss: 0.0239 - accuracy: 0.9930 - val_loss: 3.1185 - val_accuracy: 0.6463
# Epoch 83/100
# 59/59 [==============================] - 35s 600ms/step - loss: 0.0118 - accuracy: 0.9962 - val_loss: 2.9090 - val_accuracy: 0.6429
# Epoch 84/100
# 59/59 [==============================] - 34s 575ms/step - loss: 0.0121 - accuracy: 0.9973 - val_loss: 2.6923 - val_accuracy: 0.6497
# Epoch 85/100
# 59/59 [==============================] - 34s 583ms/step - loss: 0.0092 - accuracy: 0.9984 - val_loss: 2.9059 - val_accuracy: 0.6429
# Epoch 86/100
# 59/59 [==============================] - 35s 584ms/step - loss: 0.0164 - accuracy: 0.9952 - val_loss: 2.6373 - val_accuracy: 0.6837
# Epoch 87/100
# 59/59 [==============================] - 34s 574ms/step - loss: 0.0168 - accuracy: 0.9952 - val_loss: 2.7476 - val_accuracy: 0.6803
# Epoch 88/100
# 59/59 [==============================] - 34s 574ms/step - loss: 0.0198 - accuracy: 0.9946 - val_loss: 2.6366 - val_accuracy: 0.6327
# Epoch 89/100
# 59/59 [==============================] - 34s 569ms/step - loss: 0.0148 - accuracy: 0.9957 - val_loss: 2.3182 - val_accuracy: 0.6701
# Epoch 90/100
# 59/59 [==============================] - 35s 580ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 2.4610 - val_accuracy: 0.6803
# Epoch 91/100
# 59/59 [==============================] - 34s 571ms/step - loss: 0.0183 - accuracy: 0.9962 - val_loss: 2.5227 - val_accuracy: 0.6565
# Epoch 92/100
# 59/59 [==============================] - 36s 603ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 2.8572 - val_accuracy: 0.6633
# Epoch 93/100
# 59/59 [==============================] - 34s 572ms/step - loss: 0.0140 - accuracy: 0.9962 - val_loss: 2.5298 - val_accuracy: 0.6667
# Epoch 94/100
# 59/59 [==============================] - 34s 573ms/step - loss: 0.0170 - accuracy: 0.9962 - val_loss: 2.5152 - val_accuracy: 0.6871
# Epoch 95/100
# 59/59 [==============================] - 34s 572ms/step - loss: 0.0148 - accuracy: 0.9978 - val_loss: 2.6248 - val_accuracy: 0.6939
# Epoch 96/100
# 59/59 [==============================] - 35s 601ms/step - loss: 0.0096 - accuracy: 0.9978 - val_loss: 2.6963 - val_accuracy: 0.6939
# Epoch 97/100
# 59/59 [==============================] - 34s 574ms/step - loss: 0.0130 - accuracy: 0.9952 - val_loss: 2.5737 - val_accuracy: 0.6633
# Epoch 98/100
# 59/59 [==============================] - 34s 569ms/step - loss: 0.0055 - accuracy: 0.9989 - val_loss: 2.5573 - val_accuracy: 0.7041
# Epoch 99/100
# 59/59 [==============================] - 34s 574ms/step - loss: 0.0067 - accuracy: 0.9984 - val_loss: 2.8363 - val_accuracy: 0.6939
# Epoch 100/100
# 59/59 [==============================] - 34s 571ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 2.6386 - val_accuracy: 0.6803

# %%
def process_image(path):
    img = tf.image.decode_image(tf.io.read_file(path))
    img = tf.cast(img, tf.float32)
    img = img / 255.
    img = tf.image.resize(img, IMAGE_SIZE)
    img_tensor = tf.convert_to_tensor(img)
    img_tensor = tf.expand_dims(img, axis=0)
    return img_tensor

# %%
image_pred = process_image(x_test.iloc[102])
#prediction = LeNet.predict_classes(image_pred)[0]
prediction = np.argmax(LeNet.predict(image_pred),axis=1)

print(("The image is a " + str(FRUIT_TEST_CLASS_NAMES[prediction])).capitalize())
print(f'The image is predicted as a {FRUIT_TEST_CLASS_NAMES[y_test.iloc[102]]}')
# Out:
# 1/1 [==============================] - 0s 36ms/step
# The image is a ['apple___black_rot']
# The image is predicted as a Apple___Black_rot
