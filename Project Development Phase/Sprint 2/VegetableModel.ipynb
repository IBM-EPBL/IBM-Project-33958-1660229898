# %% [markdown]
# ## **VEGETABLE MODEL**

# %% [markdown]
# **Uploading vegetable Data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/NalaiyaThiran/Dataset/Veg-dataset.zip")
zip_ref.extractall()
zip_ref.close()

# %% [markdown]
# **Importing required packages**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
import random
import cv2
from tensorflow.keras import layers, models
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
import pickle
import zipfile
tf.__version__
# Out:
# '2.9.2'

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)
# Out:
# Number of replicas: 1

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
batch_size = 32
IMAGE_SIZE = [128, 128]
EPOCHS = 25

# %% [markdown]
# **Training Data**

# %%
TRAIN_PATH = "/content/Veg-dataset/train_set"

VEG_TRAIN_CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(TRAIN_PATH + "*/*"))])
VEG_TRAIN_CLASS_NAMES
# Out:
# array(['Tomato___Bacterial_spot', 'Tomato___Late_blight',
#        'Pepper,_bell___healthy', 'Tomato___Leaf_Mold',
#        'Potato___Early_blight', 'Tomato___Septoria_leaf_spot',
#        'Potato___healthy', 'Pepper,_bell___Bacterial_spot',
#        'Potato___Late_blight'], dtype='<U29')

# %%
files_train_count = []
for i,f in enumerate(VEG_TRAIN_CLASS_NAMES):
    folder_path = os.path.join(TRAIN_PATH, f)
    for path in os.listdir(os.path.join(folder_path)):
        files_train_count.append(['{}/{}'.format(folder_path,path), f, i])
veg_train_df = pd.DataFrame(files_train_count, columns=['filepath', 'class_name', 'label'])
veg_train_df.head()
# Out:
#                                             filepath               class_name  \
# 0  /content/Veg-dataset/train_set/Tomato___Bacter...  Tomato___Bacterial_spot
# 1  /content/Veg-dataset/train_set/Tomato___Bacter...  Tomato___Bacterial_spot
# 2  /content/Veg-dataset/train_set/Tomato___Bacter...  Tomato___Bacterial_spot
# 3  /content/Veg-dataset/train_set/Tomato___Bacter...  Tomato___Bacterial_spot
# 4  /content/Veg-dataset/train_set/Tomato___Bacter...  Tomato___Bacterial_spot
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
veg_train_df.class_name.value_counts()
# Out:
# Tomato___Bacterial_spot          2127
# Tomato___Late_blight             1909
# Tomato___Septoria_leaf_spot      1771
# Pepper,_bell___healthy           1478
# Potato___Early_blight            1000
# Potato___Late_blight             1000
# Pepper,_bell___Bacterial_spot     997
# Tomato___Leaf_Mold                952
# Potato___healthy                  152
# Name: class_name, dtype: int64

# %% [markdown]
# **Dealing with Class Imbalance**

# %%
quantidade_por_class = 150
veg_train_df = pd.concat([veg_train_df[veg_train_df['class_name']== i][:quantidade_por_class] for i in VEG_TRAIN_CLASS_NAMES])

# %%
veg_train_df.class_name.value_counts()
# Out:
# Tomato___Bacterial_spot          150
# Tomato___Late_blight             150
# Pepper,_bell___healthy           150
# Tomato___Leaf_Mold               150
# Potato___Early_blight            150
# Tomato___Septoria_leaf_spot      150
# Potato___healthy                 150
# Pepper,_bell___Bacterial_spot    150
# Potato___Late_blight             150
# Name: class_name, dtype: int64

# %%
image = cv2.imread(veg_train_df.filepath[40])
imgplot = plt.imshow(image)
plt.show()

# %%
x_train = veg_train_df['filepath']
y_train = veg_train_df['label']

# %%
x_train_tensor = tf.convert_to_tensor(x_train.values, dtype=tf.string)
y_train_tensor = tf.convert_to_tensor(y_train.values)

# %% [markdown]
# **Testing Data**

# %%
TEST_PATH = "/content/Veg-dataset/test_set"

VEG_TEST_CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(TEST_PATH + "*/*"))])
VEG_TEST_CLASS_NAMES
# Out:
# array(['Tomato___Bacterial_spot', 'Tomato___Late_blight',
#        'Pepper,_bell___healthy', 'Tomato___Leaf_Mold',
#        'Potato___Early_blight', 'Tomato___Septoria_leaf_spot',
#        'Potato___healthy', 'Pepper,_bell___Bacterial_spot',
#        'Potato___Late_blight'], dtype='<U29')

# %%
files_test_count = []
for i,f in enumerate(VEG_TEST_CLASS_NAMES):
    folder_test_path = os.path.join(TEST_PATH, f)
    for path in os.listdir(os.path.join(folder_test_path)):
        files_test_count.append(['{}/{}'.format(folder_test_path,path), f, i])
veg_test_df = pd.DataFrame(files_test_count, columns=['filepath', 'class_name', 'label'])
veg_test_df.head()
# Out:
#                                             filepath               class_name  \
# 0  /content/Veg-dataset/test_set/Tomato___Bacteri...  Tomato___Bacterial_spot
# 1  /content/Veg-dataset/test_set/Tomato___Bacteri...  Tomato___Bacterial_spot
# 2  /content/Veg-dataset/test_set/Tomato___Bacteri...  Tomato___Bacterial_spot
# 3  /content/Veg-dataset/test_set/Tomato___Bacteri...  Tomato___Bacterial_spot
# 4  /content/Veg-dataset/test_set/Tomato___Bacteri...  Tomato___Bacterial_spot
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
veg_test_df.class_name.value_counts()
# Out:
# Tomato___Bacterial_spot          667
# Tomato___Late_blight             599
# Pepper,_bell___healthy           448
# Tomato___Septoria_leaf_spot      421
# Tomato___Leaf_Mold               322
# Pepper,_bell___Bacterial_spot    317
# Potato___Early_blight            300
# Potato___Late_blight             290
# Potato___healthy                  52
# Name: class_name, dtype: int64

# %%
quantidade_por_class = 50
veg_test_df = pd.concat([veg_test_df[veg_test_df['class_name']== i][:quantidade_por_class] for i in VEG_TEST_CLASS_NAMES])

# %%
image = cv2.imread(veg_test_df.filepath[40])
imgplot = plt.imshow(image)
plt.show()

# %%
x_test = veg_test_df['filepath']
y_test = veg_test_df['label']

# %%
x_test_tensor = tf.convert_to_tensor(x_test.values, dtype=tf.string)
y_test_tensor = tf.convert_to_tensor(y_test.values)

# %%
train_data = tf.data.Dataset.from_tensor_slices((x_train_tensor, y_train_tensor))
test_data = tf.data.Dataset.from_tensor_slices((x_test_tensor, y_test_tensor))

# %%
def map_fn(path, label):
    image = tf.image.decode_jpeg(tf.io.read_file(path))
    return image, label
#apply the function
train_data_img = train_data.map(map_fn)
test_data_img = test_data.map(map_fn)

# %% [markdown]
# **Visualizing a sample from train and test data**

# %%
fig, ax = plt.subplots(1,2, figsize = (15,5))
for i,l in train_data_img.take(1):
    ax[0].set_title('Image from train dataset');
    ax[0].imshow(i);
for i,l in test_data_img.take(1):
    ax[1].set_title('Image from test dataset');
    ax[1].imshow(i);

# %% [markdown]
# **Preprocessing**

# %%
def preprocessing(image, label):
    """
    returns a image that is reshaped and normalized
    """
    image = tf.cast(image, tf.float32)
    image = image / 255.
    image = tf.image.resize(image, IMAGE_SIZE)
    
    return image, label


train_data_norm = train_data_img.map(preprocessing)
test_data_norm = test_data_img.map(preprocessing)

# %%
fig, ax = plt.subplots(1,2, figsize = (15,5))
for i,l in train_data_norm.take(1):
    ax[0].set_title('Image from train dataset');
    ax[0].imshow(i);
for i,l in test_data_norm.take(1):
    ax[1].set_title('Image from test dataset');
    ax[1].imshow(i);

# %%
train_batches = train_data_norm.batch(batch_size)
test_batches = test_data_norm.batch(batch_size)

for i, l in train_batches.take(1):
    print('Train Data Shape',i.shape)
for i, l in test_batches.take(1):
    print('Test Data Shape',i.shape)
# Out:
# Train Data Shape (32, 128, 128, 3)
# Test Data Shape (32, 128, 128, 3)

# %% [markdown]
# **Adding Layers**

# %%
LeNet = models.Sequential()
LeNet.add(layers.Conv2D(6, (5,5), activation = 'relu', input_shape = (128, 128, 3)))
LeNet.add(layers.AveragePooling2D())
LeNet.add(layers.Conv2D(16, (5,5), activation = 'relu'))
LeNet.add(layers.AveragePooling2D())
LeNet.add(layers.Flatten())
LeNet.add(layers.Dense(255, activation='relu'))
LeNet.add(layers.Dropout(0.2))
LeNet.add(layers.Dense(124, activation='relu'))
LeNet.add(layers.Dropout(0.2))
LeNet.add(layers.Dense(84, activation='relu'))
LeNet.add(layers.Dense(43, activation='sigmoid'))
LeNet.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 124, 124, 6)       456
#
#  average_pooling2d_2 (Averag  (None, 62, 62, 6)        0
#  ePooling2D)
#
#  conv2d_3 (Conv2D)           (None, 58, 58, 16)        2416
#
#  average_pooling2d_3 (Averag  (None, 29, 29, 16)       0
#  ePooling2D)
#
#  flatten_1 (Flatten)         (None, 13456)             0
#
#  dense_4 (Dense)             (None, 255)               3431535
#
#  dropout_2 (Dropout)         (None, 255)               0
#
#  dense_5 (Dense)             (None, 124)               31744
#
#  dropout_3 (Dropout)         (None, 124)               0
#
#  dense_6 (Dense)             (None, 84)                10500
#
#  dense_7 (Dense)             (None, 43)                3655
#
# =================================================================
# Total params: 3,480,306
# Trainable params: 3,480,306
# Non-trainable params: 0
# _________________________________________________________________

# %%
LeNet.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# **Testing**

# %%
history = LeNet.fit(train_batches, epochs=100,batch_size = 16,validation_data=(test_batches))
# Out:
# Epoch 1/100
# 43/43 [==============================] - 28s 622ms/step - loss: 4.3473 - accuracy: 0.0881 - val_loss: 3.6458 - val_accuracy: 0.1111
# Epoch 2/100
# 43/43 [==============================] - 27s 638ms/step - loss: 3.4292 - accuracy: 0.0533 - val_loss: 2.9212 - val_accuracy: 0.1111
# Epoch 3/100
# 43/43 [==============================] - 28s 655ms/step - loss: 2.8959 - accuracy: 0.0281 - val_loss: 2.5286 - val_accuracy: 0.1111
# Epoch 4/100
# 43/43 [==============================] - 28s 655ms/step - loss: 2.5744 - accuracy: 0.0652 - val_loss: 2.9001 - val_accuracy: 0.1111
# Epoch 5/100
# 43/43 [==============================] - 26s 616ms/step - loss: 2.8948 - accuracy: 0.0089 - val_loss: 2.2549 - val_accuracy: 0.1111
# Epoch 6/100
# 43/43 [==============================] - 26s 617ms/step - loss: 2.5526 - accuracy: 0.0496 - val_loss: 2.3275 - val_accuracy: 0.1111
# Epoch 7/100
# 43/43 [==============================] - 26s 614ms/step - loss: 2.4069 - accuracy: 0.0363 - val_loss: 2.2637 - val_accuracy: 0.1111
# Epoch 8/100
# 43/43 [==============================] - 27s 620ms/step - loss: 2.3402 - accuracy: 0.0133 - val_loss: 2.2202 - val_accuracy: 0.1111
# Epoch 9/100
# 43/43 [==============================] - 27s 619ms/step - loss: 2.3526 - accuracy: 0.0178 - val_loss: 2.2174 - val_accuracy: 0.1400
# Epoch 10/100
# 43/43 [==============================] - 27s 618ms/step - loss: 2.3508 - accuracy: 0.0163 - val_loss: 2.2193 - val_accuracy: 0.1111
# Epoch 11/100
# 43/43 [==============================] - 27s 618ms/step - loss: 2.3392 - accuracy: 0.0200 - val_loss: 2.2246 - val_accuracy: 0.1111
# Epoch 12/100
# 43/43 [==============================] - 27s 621ms/step - loss: 2.3274 - accuracy: 0.0156 - val_loss: 2.2175 - val_accuracy: 0.1111
# Epoch 13/100
# 43/43 [==============================] - 27s 617ms/step - loss: 2.3207 - accuracy: 0.0170 - val_loss: 2.2132 - val_accuracy: 0.1111
# Epoch 14/100
# 43/43 [==============================] - 26s 617ms/step - loss: 2.3127 - accuracy: 0.0104 - val_loss: 2.2063 - val_accuracy: 0.1489
# Epoch 15/100
# 43/43 [==============================] - 31s 724ms/step - loss: 2.3070 - accuracy: 0.0193 - val_loss: 2.1974 - val_accuracy: 0.1911
# Epoch 16/100
# 43/43 [==============================] - 26s 617ms/step - loss: 2.3030 - accuracy: 0.0081 - val_loss: 2.1824 - val_accuracy: 0.2133
# Epoch 17/100
# 43/43 [==============================] - 26s 616ms/step - loss: 2.2965 - accuracy: 0.0067 - val_loss: 2.1715 - val_accuracy: 0.1378
# Epoch 18/100
# 43/43 [==============================] - 26s 617ms/step - loss: 2.2843 - accuracy: 0.0141 - val_loss: 2.1594 - val_accuracy: 0.1467
# Epoch 19/100
# 43/43 [==============================] - 27s 617ms/step - loss: 2.2889 - accuracy: 0.0096 - val_loss: 2.1662 - val_accuracy: 0.2644
# Epoch 20/100
# 43/43 [==============================] - 26s 613ms/step - loss: 2.2843 - accuracy: 0.0222 - val_loss: 2.1980 - val_accuracy: 0.2756
# Epoch 21/100
# 43/43 [==============================] - 26s 614ms/step - loss: 2.2813 - accuracy: 0.0400 - val_loss: 2.1905 - val_accuracy: 0.1400
# Epoch 22/100
# 43/43 [==============================] - 26s 616ms/step - loss: 2.3060 - accuracy: 0.0956 - val_loss: 2.1765 - val_accuracy: 0.1844
# Epoch 23/100
# 43/43 [==============================] - 31s 722ms/step - loss: 2.2759 - accuracy: 0.0148 - val_loss: 2.1931 - val_accuracy: 0.1956
# Epoch 24/100
# 43/43 [==============================] - 26s 616ms/step - loss: 2.2768 - accuracy: 0.0748 - val_loss: 2.1470 - val_accuracy: 0.2333
# Epoch 25/100
# 43/43 [==============================] - 26s 617ms/step - loss: 2.2167 - accuracy: 0.0741 - val_loss: 3.4916 - val_accuracy: 0.1600
# Epoch 26/100
# 43/43 [==============================] - 26s 614ms/step - loss: 2.4839 - accuracy: 0.0015 - val_loss: 2.1143 - val_accuracy: 0.3044
# Epoch 27/100
# 43/43 [==============================] - 26s 613ms/step - loss: 2.2587 - accuracy: 0.1000 - val_loss: 2.1937 - val_accuracy: 0.2267
# Epoch 28/100
# 43/43 [==============================] - 26s 616ms/step - loss: 2.2316 - accuracy: 0.1400 - val_loss: 2.2089 - val_accuracy: 0.1156
# Epoch 29/100
# 43/43 [==============================] - 26s 612ms/step - loss: 2.2620 - accuracy: 0.0430 - val_loss: 2.1872 - val_accuracy: 0.1400
# Epoch 30/100
# 43/43 [==============================] - 26s 614ms/step - loss: 2.3014 - accuracy: 0.1089 - val_loss: 2.0564 - val_accuracy: 0.2511
# Epoch 31/100
# 43/43 [==============================] - 26s 616ms/step - loss: 2.2083 - accuracy: 0.0852 - val_loss: 2.0432 - val_accuracy: 0.2000
# Epoch 32/100
# 43/43 [==============================] - 26s 615ms/step - loss: 2.2171 - accuracy: 0.0644 - val_loss: 1.9873 - val_accuracy: 0.2978
# Epoch 33/100
# 43/43 [==============================] - 27s 617ms/step - loss: 2.1405 - accuracy: 0.1444 - val_loss: 1.9823 - val_accuracy: 0.2578
# Epoch 34/100
# 43/43 [==============================] - 26s 617ms/step - loss: 2.0827 - accuracy: 0.1815 - val_loss: 1.8508 - val_accuracy: 0.2978
# Epoch 35/100
# 43/43 [==============================] - 27s 618ms/step - loss: 2.0496 - accuracy: 0.1378 - val_loss: 1.9991 - val_accuracy: 0.2200
# Epoch 36/100
# 43/43 [==============================] - 26s 613ms/step - loss: 2.0124 - accuracy: 0.1452 - val_loss: 3.1055 - val_accuracy: 0.1400
# Epoch 37/100
# 43/43 [==============================] - 26s 615ms/step - loss: 1.9911 - accuracy: 0.2081 - val_loss: 7.1642 - val_accuracy: 0.1178
# Epoch 38/100
# 43/43 [==============================] - 27s 618ms/step - loss: 2.0958 - accuracy: 0.1807 - val_loss: 4.4553 - val_accuracy: 0.1178
# Epoch 39/100
# 43/43 [==============================] - 26s 615ms/step - loss: 2.1411 - accuracy: 0.2511 - val_loss: 1.9791 - val_accuracy: 0.2489
# Epoch 40/100
# 43/43 [==============================] - 31s 722ms/step - loss: 2.1874 - accuracy: 0.1326 - val_loss: 1.8398 - val_accuracy: 0.3133
# Epoch 41/100
# 43/43 [==============================] - 28s 653ms/step - loss: 1.9715 - accuracy: 0.2215 - val_loss: 1.7195 - val_accuracy: 0.3422
# Epoch 42/100
# 43/43 [==============================] - 26s 612ms/step - loss: 1.8742 - accuracy: 0.2193 - val_loss: 1.6469 - val_accuracy: 0.3622
# Epoch 43/100
# 43/43 [==============================] - 28s 652ms/step - loss: 1.8060 - accuracy: 0.1985 - val_loss: 1.5780 - val_accuracy: 0.4000
# Epoch 44/100
# 43/43 [==============================] - 27s 619ms/step - loss: 1.7181 - accuracy: 0.2385 - val_loss: 1.5108 - val_accuracy: 0.4244
# Epoch 45/100
# 43/43 [==============================] - 26s 614ms/step - loss: 1.6503 - accuracy: 0.2733 - val_loss: 1.4334 - val_accuracy: 0.4822
# Epoch 46/100
# 43/43 [==============================] - 27s 618ms/step - loss: 1.5931 - accuracy: 0.3104 - val_loss: 1.3608 - val_accuracy: 0.5022
# Epoch 47/100
# 43/43 [==============================] - 26s 614ms/step - loss: 1.5102 - accuracy: 0.3481 - val_loss: 1.2863 - val_accuracy: 0.5311
# Epoch 48/100
# 43/43 [==============================] - 31s 712ms/step - loss: 1.4389 - accuracy: 0.3852 - val_loss: 1.2273 - val_accuracy: 0.5356
# Epoch 49/100
# 43/43 [==============================] - 26s 616ms/step - loss: 1.3990 - accuracy: 0.4459 - val_loss: 1.3258 - val_accuracy: 0.4956
# Epoch 50/100
# 43/43 [==============================] - 26s 616ms/step - loss: 1.4157 - accuracy: 0.4511 - val_loss: 2.3051 - val_accuracy: 0.3489
# Epoch 51/100
# 43/43 [==============================] - 26s 611ms/step - loss: 1.5358 - accuracy: 0.3911 - val_loss: 1.1877 - val_accuracy: 0.5600
# Epoch 52/100
# 43/43 [==============================] - 26s 613ms/step - loss: 1.5199 - accuracy: 0.3837 - val_loss: 1.3420 - val_accuracy: 0.4867
# Epoch 53/100
# 43/43 [==============================] - 26s 614ms/step - loss: 1.2741 - accuracy: 0.4830 - val_loss: 1.0795 - val_accuracy: 0.6178
# Epoch 54/100
# 43/43 [==============================] - 26s 613ms/step - loss: 1.1026 - accuracy: 0.5319 - val_loss: 0.9303 - val_accuracy: 0.6844
# Epoch 55/100
# 43/43 [==============================] - 27s 618ms/step - loss: 0.9803 - accuracy: 0.5956 - val_loss: 0.8652 - val_accuracy: 0.7156
# Epoch 56/100
# 43/43 [==============================] - 27s 619ms/step - loss: 0.8792 - accuracy: 0.6496 - val_loss: 0.8085 - val_accuracy: 0.7378
# Epoch 57/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.7690 - accuracy: 0.6993 - val_loss: 0.7209 - val_accuracy: 0.8044
# Epoch 58/100
# 43/43 [==============================] - 26s 615ms/step - loss: 0.6915 - accuracy: 0.7304 - val_loss: 0.6888 - val_accuracy: 0.8222
# Epoch 59/100
# 43/43 [==============================] - 27s 618ms/step - loss: 0.6047 - accuracy: 0.7652 - val_loss: 0.6455 - val_accuracy: 0.8467
# Epoch 60/100
# 43/43 [==============================] - 26s 616ms/step - loss: 0.4877 - accuracy: 0.8296 - val_loss: 0.6235 - val_accuracy: 0.8489
# Epoch 61/100
# 43/43 [==============================] - 26s 615ms/step - loss: 0.4744 - accuracy: 0.8333 - val_loss: 0.5792 - val_accuracy: 0.8778
# Epoch 62/100
# 43/43 [==============================] - 28s 655ms/step - loss: 0.3670 - accuracy: 0.8748 - val_loss: 0.5831 - val_accuracy: 0.8933
# Epoch 63/100
# 43/43 [==============================] - 27s 618ms/step - loss: 0.3380 - accuracy: 0.8807 - val_loss: 0.6676 - val_accuracy: 0.8778
# Epoch 64/100
# 43/43 [==============================] - 26s 614ms/step - loss: 0.3218 - accuracy: 0.8815 - val_loss: 0.6704 - val_accuracy: 0.8933
# Epoch 65/100
# 43/43 [==============================] - 31s 722ms/step - loss: 0.3344 - accuracy: 0.8852 - val_loss: 0.6262 - val_accuracy: 0.8911
# Epoch 66/100
# 43/43 [==============================] - 27s 617ms/step - loss: 0.3133 - accuracy: 0.8911 - val_loss: 0.6528 - val_accuracy: 0.8933
# Epoch 67/100
# 43/43 [==============================] - 27s 618ms/step - loss: 0.4323 - accuracy: 0.8474 - val_loss: 0.6953 - val_accuracy: 0.8556
# Epoch 68/100
# 43/43 [==============================] - 26s 613ms/step - loss: 0.3394 - accuracy: 0.8844 - val_loss: 0.6865 - val_accuracy: 0.8844
# Epoch 69/100
# 43/43 [==============================] - 26s 615ms/step - loss: 0.2740 - accuracy: 0.9037 - val_loss: 0.6333 - val_accuracy: 0.9022
# Epoch 70/100
# 43/43 [==============================] - 27s 619ms/step - loss: 0.2347 - accuracy: 0.9230 - val_loss: 0.6337 - val_accuracy: 0.9022
# Epoch 71/100
# 43/43 [==============================] - 26s 615ms/step - loss: 0.2514 - accuracy: 0.9089 - val_loss: 0.5976 - val_accuracy: 0.9089
# Epoch 72/100
# 43/43 [==============================] - 28s 654ms/step - loss: 0.1969 - accuracy: 0.9326 - val_loss: 0.6062 - val_accuracy: 0.9156
# Epoch 73/100
# 43/43 [==============================] - 29s 667ms/step - loss: 0.1557 - accuracy: 0.9496 - val_loss: 0.5909 - val_accuracy: 0.9244
# Epoch 74/100
# 43/43 [==============================] - 27s 620ms/step - loss: 0.0984 - accuracy: 0.9711 - val_loss: 0.6559 - val_accuracy: 0.9289
# Epoch 75/100
# 43/43 [==============================] - 27s 619ms/step - loss: 0.0916 - accuracy: 0.9696 - val_loss: 0.6914 - val_accuracy: 0.9222
# Epoch 76/100
# 43/43 [==============================] - 27s 618ms/step - loss: 0.0836 - accuracy: 0.9770 - val_loss: 0.6982 - val_accuracy: 0.9267
# Epoch 77/100
# 43/43 [==============================] - 27s 621ms/step - loss: 0.0854 - accuracy: 0.9756 - val_loss: 0.6741 - val_accuracy: 0.9289
# Epoch 78/100
# 43/43 [==============================] - 27s 617ms/step - loss: 0.1069 - accuracy: 0.9637 - val_loss: 0.6542 - val_accuracy: 0.9333
# Epoch 79/100
# 43/43 [==============================] - 26s 617ms/step - loss: 0.0775 - accuracy: 0.9741 - val_loss: 0.6346 - val_accuracy: 0.9311
# Epoch 80/100
# 43/43 [==============================] - 31s 718ms/step - loss: 0.0557 - accuracy: 0.9785 - val_loss: 0.6422 - val_accuracy: 0.9311
# Epoch 81/100
# 43/43 [==============================] - 26s 613ms/step - loss: 0.0557 - accuracy: 0.9837 - val_loss: 0.6801 - val_accuracy: 0.9267
# Epoch 82/100
# 43/43 [==============================] - 26s 616ms/step - loss: 0.0515 - accuracy: 0.9844 - val_loss: 0.7051 - val_accuracy: 0.9244
# Epoch 83/100
# 43/43 [==============================] - 27s 617ms/step - loss: 0.0626 - accuracy: 0.9793 - val_loss: 0.6652 - val_accuracy: 0.9356
# Epoch 84/100
# 43/43 [==============================] - 27s 617ms/step - loss: 0.0548 - accuracy: 0.9822 - val_loss: 0.7037 - val_accuracy: 0.9289
# Epoch 85/100
# 43/43 [==============================] - 27s 617ms/step - loss: 0.0383 - accuracy: 0.9889 - val_loss: 0.7368 - val_accuracy: 0.9289
# Epoch 86/100
# 43/43 [==============================] - 26s 616ms/step - loss: 0.0584 - accuracy: 0.9793 - val_loss: 0.6955 - val_accuracy: 0.9289
# Epoch 87/100
# 43/43 [==============================] - 27s 618ms/step - loss: 0.0579 - accuracy: 0.9815 - val_loss: 0.7080 - val_accuracy: 0.9311
# Epoch 88/100
# 43/43 [==============================] - 28s 644ms/step - loss: 0.0542 - accuracy: 0.9822 - val_loss: 0.7470 - val_accuracy: 0.9289
# Epoch 89/100
# 43/43 [==============================] - 27s 618ms/step - loss: 0.0441 - accuracy: 0.9881 - val_loss: 0.7467 - val_accuracy: 0.9244
# Epoch 90/100
# 43/43 [==============================] - 27s 619ms/step - loss: 0.0639 - accuracy: 0.9822 - val_loss: 0.7530 - val_accuracy: 0.9244
# Epoch 91/100
# 43/43 [==============================] - 26s 617ms/step - loss: 0.0591 - accuracy: 0.9793 - val_loss: 0.7249 - val_accuracy: 0.9311
# Epoch 92/100
# 43/43 [==============================] - 26s 615ms/step - loss: 0.0896 - accuracy: 0.9741 - val_loss: 0.7386 - val_accuracy: 0.9244
# Epoch 93/100
# 43/43 [==============================] - 26s 614ms/step - loss: 0.0577 - accuracy: 0.9793 - val_loss: 0.7595 - val_accuracy: 0.9267
# Epoch 94/100
# 43/43 [==============================] - 26s 616ms/step - loss: 0.0479 - accuracy: 0.9844 - val_loss: 0.7432 - val_accuracy: 0.9289
# Epoch 95/100
# 43/43 [==============================] - 26s 616ms/step - loss: 0.0572 - accuracy: 0.9830 - val_loss: 0.7308 - val_accuracy: 0.9222
# Epoch 96/100
# 43/43 [==============================] - 26s 612ms/step - loss: 0.0543 - accuracy: 0.9837 - val_loss: 0.7275 - val_accuracy: 0.9244
# Epoch 97/100
# 43/43 [==============================] - 26s 615ms/step - loss: 0.0222 - accuracy: 0.9956 - val_loss: 0.7639 - val_accuracy: 0.9289
# Epoch 98/100
# 43/43 [==============================] - 31s 722ms/step - loss: 0.0406 - accuracy: 0.9896 - val_loss: 0.7748 - val_accuracy: 0.9267
# Epoch 99/100
# 43/43 [==============================] - 26s 612ms/step - loss: 0.0491 - accuracy: 0.9837 - val_loss: 0.7546 - val_accuracy: 0.9267
# Epoch 100/100
# 43/43 [==============================] - 26s 616ms/step - loss: 0.0542 - accuracy: 0.9830 - val_loss: 0.7138 - val_accuracy: 0.9289

# %% [markdown]
# **Prediction**

# %%
def process_image(path):
    img = tf.image.decode_image(tf.io.read_file(path))
    img = tf.cast(img, tf.float32)
    img = img / 255.
    img = tf.image.resize(img, IMAGE_SIZE)
    img_tensor = tf.convert_to_tensor(img)
    img_tensor = tf.expand_dims(img, axis=0)
    return img_tensor

# %%
image_pred = process_image(x_test.iloc[102])
#prediction = LeNet.predict_classes(image_pred)[0]
prediction = np.argmax(LeNet.predict(image_pred),axis=1)

print(("The image is a " + str(VEG_TEST_CLASS_NAMES[prediction[0]])).capitalize())
print(f'The image is predicted as a {VEG_TEST_CLASS_NAMES[y_test.iloc[102]]}')
# Out:
# 1/1 [==============================] - 0s 177ms/step
# The image is a pepper,_bell___healthy
# The image is predicted as a Pepper,_bell___healthy
